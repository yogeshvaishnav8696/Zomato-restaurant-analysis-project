# %% [markdown]
# ### potential Insights
# ### 1 Top 10 restaurants
# ### 2 Top-rated restaurants
# ### 3 Oline booking vs table booking
# ### 4 cost analysis
# ### 5 cuisine popularity

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\vmali\OneDrive\Desktop\zomato.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
df=df.drop(df.columns[[0]],axis=1)
df=df.drop(df.columns[[0]],axis=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of              restaurant name     restaurant type  rate (out of 5)  \
# 0               #FeelTheROLL         Quick Bites              3.4
# 1                 #L-81 Cafe         Quick Bites              3.9
# 2                    #refuel                Cafe              3.7
# 3         '@ Biryani Central       Casual Dining              2.7
# 4                 '@ The Bbq       Casual Dining              2.8
# ...                      ...                 ...              ...
# 7100                  Zoey's                Cafe              4.3
# 7101  ZOROY Luxury Chocolate      Dessert Parlor              4.0
# 7102       Zu's Doner Kebaps  Takeaway, Delivery              3.7
# 7103                   Zyara       Casual Dining              3.8
# 7104                  Zyksha          Food Truck              3.4
#
#       num of ratings  avg cost (two people) online_order table booking  \
# ...

# %%
df.isnull().sum()
# Out:
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %%
df.shape
# Out:
# (7105, 10)

# %%
df.columns
# Out:
# Index(['restaurant name', 'restaurant type', 'rate (out of 5)',
#        'num of ratings', 'avg cost (two people)', 'online_order',
#        'table booking', 'cuisines type', 'area', 'local address'],
#       dtype='object')

# %%
df.head()
# Out:
#       restaurant name restaurant type  rate (out of 5)  num of ratings  \
# 0        #FeelTheROLL     Quick Bites              3.4               7
# 1          #L-81 Cafe     Quick Bites              3.9              48
# 2             #refuel            Cafe              3.7              37
# 3  '@ Biryani Central   Casual Dining              2.7             135
# 4          '@ The Bbq   Casual Dining              2.8              40
#
#    avg cost (two people) online_order table booking  \
# 0                  200.0           No            No
# 1                  400.0          Yes            No
# 2                  400.0          Yes            No
# 3                  550.0          Yes            No
# 4                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# 1                               Fast Food, Beverages
# 2                                    Cafe, Beverages
# ...

# %%
df.nunique()
# Out:
# restaurant name          7105
# restaurant type            81
# rate (out of 5)            31
# num of ratings            935
# avg cost (two people)      65
# online_order                2
# table booking               2
# cuisines type            2175
# area                       30
# local address              90
# dtype: int64

# %%
df.describe()
# Out:
#        rate (out of 5)  num of ratings  avg cost (two people)
# count      7037.000000     7105.000000            7048.000000
# mean          3.514253      188.921042             540.286464
# std           0.463249      592.171049             462.902305
# min           1.800000        1.000000              40.000000
# 25%           3.200000       16.000000             300.000000
# 50%           3.500000       40.000000             400.000000
# 75%           3.800000      128.000000             600.000000
# max           4.900000    16345.000000            6000.000000

# %%
df[['restaurant name','rate (out of 5)' ,'num of ratings' ]].sort_values(by=['num of ratings'],ascending=False)
# Out:
#                                     restaurant name  rate (out of 5)  \
# 1035                    Byg Brewski Brewing Company              4.9
# 6665                                           Toit              4.7
# 6242                                The Black Pearl              4.7
# 770                                     Big Pitcher              4.6
# 423                           Arbor Brewing Company              4.5
# ...                                             ...              ...
# 1183                                Cake of the Day              3.2
# 2247                                     Fresh Bowl              3.3
# 2434  Great Moments - Hotel Bangalore International              3.2
# 2588  Height's Cafe - Hotel Bangalore International              3.2
# 2968                                           Irie              3.2
#
#       num of ratings
# 1035           16345
# 6665           14956
# 6242           10413
# 770             9272
# 423             8375
# ...

# %% [markdown]
# ### Top 10 Restaurant Types in Zomato

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='restaurant type', data=df, order=df['restaurant type'].value_counts().index[:10])
plt.title('Top 10 Restaurant Types in Zomato ')
plt.xlabel('Restaurant Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Distribution of Ratings in Zomato

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['rate (out of 5)'], bins=10, edgecolor='skyblue')
plt.title('Distribution of Ratings in Zomato ')
plt.xlabel('Rating (out of 5)')
plt.ylabel('Frequency')
plt.show()

# %%
df['online_order'].value_counts()
# Out:
# online_order
# Yes    3727
# No     3378
# Name: count, dtype: int64

# %%
df['table booking'].value_counts()
# Out:
# table booking
# No     6361
# Yes     744
# Name: count, dtype: int64

# %% [markdown]
# ### Proportion of Restaurants with Online Order and offline order in Zomato

# %%
online_order_counts = df['online_order'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(online_order_counts, labels=['Online Order', 'Offline Order'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Proportion of Restaurants with Online Ordering in Zomato ')
plt.show()

# %% [markdown]
# ### Top 10 Restaurants by Average Cost for Two People (Highest Cost)

# %%
df[['restaurant name','avg cost (two people)']].sort_values(by='avg cost (two people)' , ascending=False)[:10]
# Out:
#                              restaurant name  avg cost (two people)
# 3561  Le Cirque Signature - The Leela Palace                 6000.0
# 5090              Royal Afghan - ITC Windsor                 5000.0
# 3761                  Malties - Radisson Blu                 4500.0
# 3485              La Brasserie - Le Meridien                 4100.0
# 2448             Grill 99 - The Ritz-Carlton                 4000.0
# 1677                   Dakshin - ITC Windsor                 4000.0
# 218             Alba - JW Marriott Bengaluru                 4000.0
# 2002     Edo Restaurant & Bar - ITC Gardenia                 4000.0
# 5040                Riwaz - The Ritz-Carlton                 4000.0
# 1942    Dum Pukht Jolly Nabobs - ITC Windsor                 4000.0

# %%
plt.figure(figsize=(10, 6))
plt.barh(top_restaurants['restaurant name'], top_restaurants['avg cost (two people)'], color='lightcoral')
plt.title('Top 10 Restaurants by Average Cost for Two People (Highest Cost)')
plt.xlabel('Average Cost (Two People)')
plt.ylabel('Restaurant Name')
plt.show()

# %% [markdown]
# ### Top chipest restaurant for two people

# %%
df[['restaurant name','avg cost (two people)']].sort_values(by='avg cost (two people)' , ascending=True)[:10]
# Out:
#                restaurant name  avg cost (two people)
# 5849     Srinidhi Sagar Deluxe                   40.0
# 5850  Srinidhi Sagar Food Line                   40.0
# 5303               Savera Cafe                   50.0
# 4230         Nellore Dosa Camp                   70.0
# 4144                   Namaste                   70.0
# 1938                 Dtink Lab                   80.0
# 1906                 Dosa Cafe                   80.0
# 597            Bangarpet Chats                   80.0
# 3455           Kulhad Junction                  100.0
# 255                     AM WOW                  100.0

# %%
plt.figure(figsize=(10, 6))
plt.barh(top_restaurants['restaurant name'], top_restaurants['avg cost (two people)'], color='skyblue')
plt.title('Top 10 Restaurants by Average Cost for Two People (Lowest Cost)')
plt.xlabel('Average Cost (Two People)')
plt.ylabel('Restaurant Name')
plt.show()

# %% [markdown]
# ### Top 10 Restaurants by Average Cost for Two People

# %%
top_restaurants = df[['restaurant name', 'avg cost (two people)']].sort_values(by='avg cost (two people)', ascending=True)[:10]

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(top_restaurants['restaurant name'], top_restaurants['avg cost (two people)'], color='lightgreen')
plt.title('Top 10 Restaurants by Average Cost for Two People')
plt.xlabel('Average Cost (Two People)')
plt.ylabel('Restaurant Name')
plt.show()

# %% [markdown]
# ### 10 most cuisines type

# %%
df['cuisines type'].value_counts()[:10].to_frame()
# Out:
#                                      count
# cuisines type
# North Indian, Chinese                  421
# North Indian                           420
# South Indian                           348
# Fast Food                              140
# South Indian, North Indian, Chinese    128
# Biryani                                122
# Bakery, Desserts                        97
# Desserts                                87
# Cafe                                    85
# Bakery                                  77

# %%
top_cuisines = df['cuisines type'].value_counts()[:10]
plt.figure(figsize=(12,8))
top_cuisines.plot(kind='bar', color='skyblue')
plt.title('Top 10 Cuisines Types')
plt.xlabel('Cuisine Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 10 lowest cuisines type

# %%
df['cuisines type'].value_counts()[-10:].to_frame()
# Out:
#                                                  count
# cuisines type
# Continental, Pizza, Burger                           1
# North Indian, Mughlai, Seafood, Chinese              1
# Arabian, Chinese, North Indian, Kerala, Seafood      1
# Mithai, Street Food, Fast Food                       1
# South Indian, Kerala, Seafood                        1
# Seafood, Andhra                                      1
# Beverages, Cafe, Desserts, Spanish, Bakery           1
# Goan, Seafood, North Indian, Chinese, Biryani        1
# Healthy Food, Cafe, Beverages                        1
# Turkish, Fast Food, Biryani, Chinese                 1

# %%
top_cuisines = df['cuisines type'].value_counts()[:10]

# Plotting
plt.figure(figsize=(12,8))
top_cuisines.plot(kind='bar', color='lightgreen')
plt.title('lowest 10 Cuisines Types')
plt.xlabel('Cuisine Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.title('Area distribution')
df['area'].value_counts().head(10).plot(kind='bar' , xlabel='area' , ylabel='number' ,
                                        title='Area distribution' , color='c')
plt.show()

# %%
df['local address'].value_counts()[:10].plot(kind='bar' , xlabel='Address' , ylabel='number' ,
                                        title='Local Address distribution' , color='purple')
plt.show()
